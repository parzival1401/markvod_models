# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()
Pkg.status()
# Out:
#   Activating project at `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test`
# Status `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Project.toml`
#   [033835bb] JLD2 v0.6.2

# %%
Pkg.add("JLD2")
Pkg.add("GLMakie")
Pkg.add("Random")
Pkg.add("Distributions")
Pkg.add("Optim")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Project.toml`
#   No Changes to `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Manifest.toml`
#    Resolving package versions...
#    Installed Xorg_libXfixes_jll ─ v6.0.2+0
#    Installed SIMD ─────────────── v3.7.2
#    Installed Compat ───────────── v4.18.1
#    Installed Libuuid_jll ──────── v2.41.2+0
#    Installed Libmount_jll ─────── v2.41.2+0
#    Installed OpenSSL_jll ──────── v3.5.4+0
#    Installed Adapt ────────────── v4.4.0
#    Installed SpecialFunctions ─── v2.6.1
#    Installed Distributions ────── v0.25.122
#     Updating `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Project.toml`
#   [e9467ef8] + GLMakie v0.13.6
# ...

# %%
Pkg.add("SMLMSim")
# Out:
#    Resolving package versions...
#    Installed SciMLPublic ── v1.0.0
#    Installed Static ─────── v1.3.0
#    Installed XML2_jll ───── v2.13.9+0
#    Installed Polynomials ── v4.1.0
#    Installed PrettyTables ─ v3.0.11
#     Updating `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Project.toml`
# ⌃ [5a0a87e4] + SMLMSim v0.1.3
#     Updating `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Manifest.toml`
#   [ec485272] + ArnoldiMethod v0.4.0
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [e1450e63] + BufferedStreams v1.2.2
#   [2a0fbf3d] + CPUSummary v0.2.7
#   [336ed68f] + CSV v0.10.15
#   [aafaddc9] + CatIndices v0.2.2
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [aaaa29a8] + Clustering v0.15.8
#   [944b1d66] + CodecZlib v0.7.8
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.4
# ...

# %%
Pkg.add("CairoMakie")
# Out:
#    Resolving package versions...
#     Updating `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Project.toml`
#   [13f3f980] + CairoMakie v0.15.6
#     Updating `~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/Manifest.toml`
#   [159f3aea] + Cairo v1.1.1
#   [13f3f980] + CairoMakie v0.15.6
# Precompiling project...
#   82697.1 ms  ✓ CairoMakie
#   1 dependency successfully precompiled in 88 seconds. 424 already precompiled.

# %%
include("/Users/fernandodelgado/Documents/university /fall 2024/markov model/markvod_models/generated_data/types/types_with_data.jl")
# Out:
# ERROR: LoadError: MethodError: no method matching length(::ComputePipeline.Computed)
# The function `length` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   length(::LibGit2.GitStatus)
#    @ LibGit2 /opt/homebrew/Cellar/julia/1.11.3/share/julia/stdlib/v1.11/LibGit2/src/status.jl:21
#   length(::Automa.ByteSet)
#    @ Automa ~/.julia/packages/Automa/EyNRt/src/byteset.jl:7
#   length(::DataStructures.SparseIntSet)
#    @ DataStructures ~/.julia/packages/DataStructures/IrAJn/src/sparse_int_set.jl:61
#   ...
#
# Stacktrace:
#   [1] _similar_shape(itr::ComputePipeline.Computed, ::Base.HasLength)
#     @ Base ./array.jl:663
#   [2] _collect(cont::UnitRange{Int64}, itr::ComputePipeline.Computed, ::Base.HasEltype, isz::Base.HasLength)
#     @ Base ./array.jl:722
#   [3] collect(itr::ComputePipeline.Computed)
#     @ Base ./array.jl:716
#   [4] broadcastable(x::ComputePipeline.Computed)
#     @ Base.Broadcast ./broadcast.jl:712
# ...

# %%
using JLD2
@load "/Users/fernandodelgado/Documents/university /fall 2024/markov model/markvod_models/generated_data/simulation_data.jld2" p1 p2 states steps k
# Out:
# 5-element Vector{Symbol}:
#  :p1
#  :p2
#  :states
#  :steps
#  :k

# %%
optimize_parameters(p1, p2, states, steps, k)
# Out:
# UndefVarError: `optimize_parameters` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/university /fall 2024/markov model/markvod_models/generated_data/test/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:1
